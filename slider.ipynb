# %%
import ipywidgets as w
from IPython.display import display

# %%
slider = w.IntSlider(value=10,
                     min=0,
                     max=20,
                     description="forward primer")
display(slider)
# Out:
# IntSlider(value=10, description='forward primer', max=20)

# %%
slider.value
# Out:
# 10
